# %% [markdown]
# # Donnée importante MV
#
# ## Second order
#
# | K  | T1  | T2  | theta|
# |---|---|---|---|
# | 0.320 | 149.53 | 15.07 | 4.00 |
#
# ## First order
#
# | K  | T | theta|
# |---|---|---|
# | 0.319 | 148.94 | 20.83 |
#
# ## Methode graphique
#
# | K  | T | theta|
# |---|---|---|
# | 0.319 | 148.94 | 20.83 |
#
# # Donnée importante DV
#
# ## Second order
#
# | K  | T1  | T2  | theta|
# |---|---|---|---|
# | 0.36255533921521593 | 170.7770252576119 | 6.12569974510096 | 5.431848706357882 |
#
# ## First order
#
# | K  | T | theta|
# |---|---|---|
# | 0.36273769970295805| 171.36277670168337 | 11.497422823838285 |
